# %%
import pandas as pd
df=pd.read_csv("zomato_restaurants_in_India.csv")
df
# Out:
#         Unnamed: 0    res_id                            name  \
# 0                0   3400299                     Bikanervala
# 1                1   3400005  Mama Chicken Mama Franky House
# 2                2   3401013                   Bhagat Halwai
# 3                3   3400290                   Bhagat Halwai
# 4                4   3401744     The Salt Cafe Kitchen & Bar
# ...            ...       ...                             ...
# 211939      211939   3202251  Kali Mirch Cafe And Restaurant
# 211940      211940   3200996                      Raju Omlet
# 211941      211941  18984164                The Grand Thakar
# 211942      211942   3201138                          Subway
# 211943      211943  18879846     Freshco's - The Health Cafe
#
#             establishment                                                url  \
# 0         ['Quick Bites']  https://www.zomato.com/agra/bikanervala-khanda...
# ...

# %%
df.res_id.duplicated().sum()
# Out:
# 156376

# %%
df.drop_duplicates(subset=["res_id"],keep="first",inplace=False).shape
# Out:
# (55568, 27)

# %%
#cleaning data
df2=df.drop(columns=["url","currency","zipcode","country_id","takeaway"])

# %%
df1=df2.drop_duplicates(subset='res_id')
df1
# Out:
#         Unnamed: 0    res_id                            name  \
# 0                0   3400299                     Bikanervala
# 1                1   3400005  Mama Chicken Mama Franky House
# 2                2   3401013                   Bhagat Halwai
# 3                3   3400290                   Bhagat Halwai
# 4                4   3401744     The Salt Cafe Kitchen & Bar
# ...            ...       ...                             ...
# 211882      211882  19142822           Shree Janta Ice Cream
# 211925      211925  18984164                The Grand Thakar
# 211926      211926  18019952                     Geeta lodge
# 211940      211940   3200996                      Raju Omlet
# 211942      211942   3201138                          Subway
#
#               establishment  \
# 0           ['Quick Bites']
# 1           ['Quick Bites']
# 2           ['Quick Bites']
# 3           ['Quick Bites']
# 4         ['Casual Dining']
# ...                     ...
# ...

# %%
df1.to_csv("finaldatacleaning.csv")

# %%
df1=pd.read_csv("finaldatacleaning.csv")
df1
# Out:
#        Unnamed: 0.1  Unnamed: 0    res_id                            name  \
# 0                 0           0   3400299                     Bikanervala
# 1                 1           1   3400005  Mama Chicken Mama Franky House
# 2                 2           2   3401013                   Bhagat Halwai
# 3                 3           3   3400290                   Bhagat Halwai
# 4                 4           4   3401744     The Salt Cafe Kitchen & Bar
# ...             ...         ...       ...                             ...
# 55563        211882      211882  19142822           Shree Janta Ice Cream
# 55564        211925      211925  18984164                The Grand Thakar
# 55565        211926      211926  18019952                     Geeta lodge
# 55566        211940      211940   3200996                      Raju Omlet
# 55567        211942      211942   3201138                          Subway
#
#              establishment                                            address  \
# ...
