# %%
import pandas as pd
df=pd.read_csv("zomato_restaurants_in_India.csv")
df
# Out:
#         Unnamed: 0    res_id                            name  \
# 0                0   3400299                     Bikanervala
# 1                1   3400005  Mama Chicken Mama Franky House
# 2                2   3401013                   Bhagat Halwai
# 3                3   3400290                   Bhagat Halwai
# 4                4   3401744     The Salt Cafe Kitchen & Bar
# ...            ...       ...                             ...
# 211939      211939   3202251  Kali Mirch Cafe And Restaurant
# 211940      211940   3200996                      Raju Omlet
# 211941      211941  18984164                The Grand Thakar
# 211942      211942   3201138                          Subway
# 211943      211943  18879846     Freshco's - The Health Cafe
#
#             establishment                                                url  \
# 0         ['Quick Bites']  https://www.zomato.com/agra/bikanervala-khanda...
# ...

# %%
df.res_id.duplicated().sum()
# Out:
# 156376

# %%
df.loc[df.res_id.duplicated(keep="first")]
# Out:
#         Unnamed: 0    res_id                            name  \
# 101            101   3400059           Peshawri - ITC Mughal
# 116            116   3400060           Taj Bano - ITC Mughal
# 140            140   3400017                  Pinch Of Spice
# 141            141   3400018                  Pinch Of Spice
# 142            142   3400850                      Urban Deck
# ...            ...       ...                             ...
# 211937      211937  18855810             Biryani aur Baatein
# 211938      211938  18662583                     Wok On Fire
# 211939      211939   3202251  Kali Mirch Cafe And Restaurant
# 211941      211941  18984164                The Grand Thakar
# 211943      211943  18879846     Freshco's - The Health Cafe
#
#             establishment                                                url  \
# 101       ['Fine Dining']  https://www.zomato.com/agra/peshawri-itc-mugha...
# ...

# %%
df.drop_duplicates(subset=["res_id"],keep="first",inplace=False).shape
# Out:
# (55568, 27)

# %%
df['city'].nunique() #uniquecity
# Out:
# 99

# %%
df['name'].nunique()  #uniques resturents
# Out:
# 41100

# %%
df.size
# Out:
# 5722488

# %%
df.shape[1]  #columns
# Out:
# 27

# %%
df.shape[0] #rows
# Out:
# 211944

# %%
df.drop(columns="takeaway")
# Out:
#         Unnamed: 0    res_id                            name  \
# 0                0   3400299                     Bikanervala
# 1                1   3400005  Mama Chicken Mama Franky House
# 2                2   3401013                   Bhagat Halwai
# 3                3   3400290                   Bhagat Halwai
# 4                4   3401744     The Salt Cafe Kitchen & Bar
# ...            ...       ...                             ...
# 211939      211939   3202251  Kali Mirch Cafe And Restaurant
# 211940      211940   3200996                      Raju Omlet
# 211941      211941  18984164                The Grand Thakar
# 211942      211942   3201138                          Subway
# 211943      211943  18879846     Freshco's - The Health Cafe
#
#             establishment                                                url  \
# 0         ['Quick Bites']  https://www.zomato.com/agra/bikanervala-khanda...
# ...

# %%
df.isnull()
# Out:
#         Unnamed: 0  res_id   name  establishment    url  address   city  \
# 0            False   False  False          False  False    False  False
# 1            False   False  False          False  False    False  False
# 2            False   False  False          False  False    False  False
# 3            False   False  False          False  False    False  False
# 4            False   False  False          False  False    False  False
# ...            ...     ...    ...            ...    ...      ...    ...
# 211939       False   False  False          False  False    False  False
# 211940       False   False  False          False  False    False  False
# 211941       False   False  False          False  False    False  False
# 211942       False   False  False          False  False    False  False
# 211943       False   False  False          False  False    False  False
#
#         city_id  locality  latitude  ...  price_range  currency  highlights  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# res_id                       0
# name                         0
# establishment                0
# url                          0
# address                    134
# city                         0
# city_id                      0
# locality                     0
# latitude                     0
# longitude                    0
# zipcode                 163187
# country_id                   0
# locality_verbose             0
# cuisines                  1391
# timings                   3874
# average_cost_for_two         0
# price_range                  0
# currency                     0
# highlights                   0
# aggregate_rating             0
# rating_text                  0
# votes                        0
# photo_count                  0
# opentable_support           48
# delivery                     0
# takeaway                     0
# dtype: int64

# %%
df1=df.dropna() #remove null value
df1
# Out:
#         Unnamed: 0    res_id                                name  \
# 1                1   3400005      Mama Chicken Mama Franky House
# 2                2   3401013                       Bhagat Halwai
# 3                3   3400290                       Bhagat Halwai
# 6                6   3400296                 Honeydew Restaurant
# 9                9   3400838                       Sugar N Thyme
# ...            ...       ...                                 ...
# 211929      211929   3200477  Chhappanbhog Restaurant & Banquets
# 211930      211930   3200560                         Mr Toasties
# 211932      211932   3201502                         Cafe Madrid
# 211939      211939   3202251      Kali Mirch Cafe And Restaurant
# 211943      211943  18879846         Freshco's - The Health Cafe
#
#             establishment                                                url  \
# 1         ['Quick Bites']  https://www.zomato.com/agra/mama-chicken-mama-...
# ...

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0              0
# res_id                  0
# name                    0
# establishment           0
# url                     0
# address                 0
# city                    0
# city_id                 0
# locality                0
# latitude                0
# longitude               0
# zipcode                 0
# country_id              0
# locality_verbose        0
# cuisines                0
# timings                 0
# average_cost_for_two    0
# price_range             0
# currency                0
# highlights              0
# aggregate_rating        0
# rating_text             0
# votes                   0
# photo_count             0
# opentable_support       0
# delivery                0
# takeaway                0
# dtype: int64

# %%
df1.shape[0]
# Out:
# 48378

# %%
df1.shape[1]
# Out:
# 27

# %%
df1.to_csv("zomatoproject.csv",header=True,index=False)

# %%
df1=pd.read_csv("zomatoproject.csv")
df1
# Out:
#        Unnamed: 0    res_id                                name  \
# 0               1   3400005      Mama Chicken Mama Franky House
# 1               2   3401013                       Bhagat Halwai
# 2               3   3400290                       Bhagat Halwai
# 3               6   3400296                 Honeydew Restaurant
# 4               9   3400838                       Sugar N Thyme
# ...           ...       ...                                 ...
# 48373      211929   3200477  Chhappanbhog Restaurant & Banquets
# 48374      211930   3200560                         Mr Toasties
# 48375      211932   3201502                         Cafe Madrid
# 48376      211939   3202251      Kali Mirch Cafe And Restaurant
# 48377      211943  18879846         Freshco's - The Health Cafe
#
#            establishment                                                url  \
# 0        ['Quick Bites']  https://www.zomato.com/agra/mama-chicken-mama-...
# ...

# %%
list(df1["city"].unique())
# Out:
# ['Agra',
#  'Ahmedabad',
#  'Gandhinagar',
#  'Ajmer',
#  'Allahabad',
#  'Amravati',
#  'Amritsar',
#  'Aurangabad',
#  'Bangalore',
#  'Bhopal',
#  'Bhubaneshwar',
#  'Mohali',
#  'Chandigarh',
#  'Panchkula',
#  'Zirakpur',
#  'Chennai',
#  'Coimbatore',
#  'Cuttack',
#  'Darjeeling',
#  'Dehradun',
#  'New Delhi',
#  'Gurgaon',
#  'Noida',
#  'Ghaziabad',
#  'Faridabad',
#  'Greater Noida',
#  'Dharamshala',
#  'Gangtok',
#  'Goa',
#  'Gorakhpur',
#  'Guntur',
#  'Guwahati',
#  'Gwalior',
#  'Haridwar',
#  'Hyderabad',
#  'Secunderabad',
#  'Indore',
#  'Jabalpur',
#  'Jaipur',
#  'Jalandhar',
#  'Jammu',
#  'Jamnagar',
#  'Jamshedpur',
#  'Jhansi',
#  'Jodhpur',
#  'Junagadh',
#  'Kanpur',
#  'Kharagpur',
#  'Kochi',
#  'Kolhapur',
#  'Kolkata',
#  'Howrah',
#  'Kota',
#  'Lucknow',
#  'Ludhiana',
#  'Madurai',
#  'Manali',
#  'Mangalore',
#  'Udupi',
#  'Manipal',
#  'Meerut',
#  'Mumbai',
#  'Navi Mumbai',
#  'Thane',
#  'Mussoorie',
#  'Mysore',
#  'Nagpur',
#  'Nainital',
# ...

# %%
df1.drop_duplicates(subset=["city"],keep="first",inplace=False)
# Out:
#        Unnamed: 0    res_id                            name  \
# 0               1   3400005  Mama Chicken Mama Franky House
# 613          2622  18757684                      Ph Se Food
# 654          2709  19011348            Wooddy Jhone's Pizza
# 1963         5936  18687544         Mango Masala Restaurant
# 2588        11153   2400390             Haldiram Bhujiawala
# ...           ...       ...                             ...
# 46823      200182   3900267               Roma's Café Diner
# 47282      202694  18739882              The Drunken Monkey
# 47323      204763  18696244        Naidu Gari Kunda Biryani
# 47546      206928   2800901                        Paradise
# 47851      209266   3201094                  Charcoal House
#
#            establishment                                                url  \
# 0        ['Quick Bites']  https://www.zomato.com/agra/mama-chicken-mama-...
# 613    ['Casual Dining']  https://www.zomato.com/ahmedabad/ph-se-food-bo...
# ...
